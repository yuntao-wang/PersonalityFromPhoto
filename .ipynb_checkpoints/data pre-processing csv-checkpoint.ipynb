# %%
import numpy as np
import pandas as pd
import glob
import json

# %% [markdown]
# ## Data Pre-processing

# %%
# read in csv file generated by Amazon API
path = r'C:\Users\movin\Documents\GitHub\PersonalityFromPhoto\data'
allFiles = glob.glob(path + '/*.csv')
df = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_, index_col=None, header=0)
    list_.append(df)
df = pd.concat(list_, ignore_index=True)

# %%
len(df.index)
# Out:
# 15997

# %%
df.head()
# Out:
#    Unnamed: 0                             fileName  \
# 0           0   Facebook/ENFJ/1000006876806379.jpg
# 1           1   Facebook/ENFJ/1001091583356351.jpg
# 2           2   Facebook/ENFJ/1001328126675771.jpg
# 3           3  Facebook/ENFJ/10100163853254202.jpg
# 4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...
# 1                                                 []
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...
# 3                                                 []
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...

# %%
# rename the unnamed column
df = df.rename(columns={'Unnamed: 0': 'GroupIndex'})

# %%
# add an index column
df['index'] = np.arange(len(df.index))

# %%
cols = df.columns.tolist()
cols
# Out:
# ['GroupIndex', 'fileName', 'Labels', 'FaceDetails', 'index']

# %%
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['index', 'GroupIndex', 'fileName', 'Labels', 'FaceDetails']

# %%
df = df[cols]

# %%
df.head()
# Out:
#    index  GroupIndex                             fileName  \
# 0      0           0   Facebook/ENFJ/1000006876806379.jpg
# 1      1           1   Facebook/ENFJ/1001091583356351.jpg
# 2      2           2   Facebook/ENFJ/1001328126675771.jpg
# 3      3           3  Facebook/ENFJ/10100163853254202.jpg
# 4      4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...
# 1                                                 []
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...
# 3                                                 []
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...

# %%
# get the personality for every photo
personality_list = []
for i in range(len(df.index)):
    personality_list.append(df['fileName'][i][9:13])
len(personality_list)
# Out:
# 15997

# %%
personality_list[:10]
# Out:
# ['ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ',
#  'ENFJ']

# %%
personality_list[-10:]
# Out:
# ['ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP',
#  'ISTP']

# %%
# add the personality column to dataframe
se = pd.Series(personality_list)
df['Personality'] = se.values
df.head()
# Out:
#    index  GroupIndex                             fileName  \
# 0      0           0   Facebook/ENFJ/1000006876806379.jpg
# 1      1           1   Facebook/ENFJ/1001091583356351.jpg
# 2      2           2   Facebook/ENFJ/1001328126675771.jpg
# 3      3           3  Facebook/ENFJ/10100163853254202.jpg
# 4      4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                 []        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                 []        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ

# %%
df.tail()
# Out:
#        index  GroupIndex                            fileName  \
# 15992  15992         995  Facebook/ISTP/1522341501192227.jpg
# 15993  15993         996  Facebook/ISTP/1522843721140384.jpg
# 15994  15994         997  Facebook/ISTP/1523030107783316.jpg
# 15995  15995         998   Facebook/ISTP/152404242162230.jpg
# 15996  15996         999  Facebook/ISTP/1524525840928834.jpg
#
#                                                   Labels  \
# 15992  [{'Name': 'Glasses', 'Confidence': 91.36360931...
# 15993  [{'Name': 'Human', 'Confidence': 99.3121795654...
# 15994  [{'Name': 'People', 'Confidence': 99.251564025...
# 15995  [{'Name': 'Emblem', 'Confidence': 99.133453369...
# 15996  [{'Name': 'People', 'Confidence': 99.210029602...
#
#                                              FaceDetails Personality
# 15992  [{'BoundingBox': {'Width': 1.0522222518920898,...        ISTP
# 15993  [{'BoundingBox': {'Width': 0.6979812383651733,...        ISTP
# 15994  [{'BoundingBox': {'Width': 0.38461539149284363...        ISTP
# 15995                                                 []        ISTP
# 15996  [{'BoundingBox': {'Width': 1.0099999904632568,...        ISTP

# %%
# empty face details number
count = 0
for i in df['FaceDetails']:
    if len(i)==2:
        count += 1

# %%
count
# Out:
# 3409

# %%
# replace empty face detail with NaN
df = df.replace('[]', np.nan)

# %%
df.tail()
# Out:
#        index  GroupIndex                            fileName  \
# 15992  15992         995  Facebook/ISTP/1522341501192227.jpg
# 15993  15993         996  Facebook/ISTP/1522843721140384.jpg
# 15994  15994         997  Facebook/ISTP/1523030107783316.jpg
# 15995  15995         998   Facebook/ISTP/152404242162230.jpg
# 15996  15996         999  Facebook/ISTP/1524525840928834.jpg
#
#                                                   Labels  \
# 15992  [{'Name': 'Glasses', 'Confidence': 91.36360931...
# 15993  [{'Name': 'Human', 'Confidence': 99.3121795654...
# 15994  [{'Name': 'People', 'Confidence': 99.251564025...
# 15995  [{'Name': 'Emblem', 'Confidence': 99.133453369...
# 15996  [{'Name': 'People', 'Confidence': 99.210029602...
#
#                                              FaceDetails Personality
# 15992  [{'BoundingBox': {'Width': 1.0522222518920898,...        ISTP
# 15993  [{'BoundingBox': {'Width': 0.6979812383651733,...        ISTP
# 15994  [{'BoundingBox': {'Width': 0.38461539149284363...        ISTP
# 15995                                                NaN        ISTP
# 15996  [{'BoundingBox': {'Width': 1.0099999904632568,...        ISTP

# %%
# drop empty value
df = df.dropna()

# %%
df.tail()
# Out:
#        index  GroupIndex                            fileName  \
# 15990  15990         993  Facebook/ISTP/1520202358072757.jpg
# 15992  15992         995  Facebook/ISTP/1522341501192227.jpg
# 15993  15993         996  Facebook/ISTP/1522843721140384.jpg
# 15994  15994         997  Facebook/ISTP/1523030107783316.jpg
# 15996  15996         999  Facebook/ISTP/1524525840928834.jpg
#
#                                                   Labels  \
# 15990  [{'Name': 'Human', 'Confidence': 99.3152389526...
# 15992  [{'Name': 'Glasses', 'Confidence': 91.36360931...
# 15993  [{'Name': 'Human', 'Confidence': 99.3121795654...
# 15994  [{'Name': 'People', 'Confidence': 99.251564025...
# 15996  [{'Name': 'People', 'Confidence': 99.210029602...
#
#                                              FaceDetails Personality
# 15990  [{'BoundingBox': {'Width': 0.4788888990879059,...        ISTP
# 15992  [{'BoundingBox': {'Width': 1.0522222518920898,...        ISTP
# 15993  [{'BoundingBox': {'Width': 0.6979812383651733,...        ISTP
# 15994  [{'BoundingBox': {'Width': 0.38461539149284363...        ISTP
# 15996  [{'BoundingBox': {'Width': 1.0099999904632568,...        ISTP

# %%
len(df)
# Out:
# 12580

# %% [markdown]
# ## Face Detail Value

# %%
df['FaceDetails'][15996]
# Out:
# "[{'BoundingBox': {'Width': 1.0099999904632568, 'Height': 1.0099999904632568, 'Left': -0.17888888716697693, 'Top': -0.10444444417953491}, 'AgeRange': {'Low': 15, 'High': 25}, 'Smile': {'Value': True, 'Confidence': 90.81520080566406}, 'Eyeglasses': {'Value': False, 'Confidence': 93.44303894042969}, 'Sunglasses': {'Value': False, 'Confidence': 99.92829895019531}, 'Gender': {'Value': 'Female', 'Confidence': 100.0}, 'Beard': {'Value': False, 'Confidence': 99.99625396728516}, 'Mustache': {'Value': False, 'Confidence': 99.999267578125}, 'EyesOpen': {'Value': True, 'Confidence': 99.99658203125}, 'MouthOpen': {'Value': False, 'Confidence': 99.9348373413086}, 'Emotions': [{'Type': 'CALM', 'Confidence': 58.72126388549805}, {'Type': 'HAPPY', 'Confidence': 55.22835159301758}, {'Type': 'CONFUSED', 'Confidence': 3.6207854747772217}], 'Landmarks': [{'Type': 'eyeLeft', 'X': 0.2096046805381775, 'Y': 0.35737723112106323}, {'Type': 'eyeRight', 'X': 0.5451221466064453, 'Y': 0.33994126319885254}, {'Type': 'nose', 'X': 0.4138149917125702, 'Y': 0.5268155932426453}, {'Type': 'mouthLeft', 'X': 0.2641378939151764, 'Y': 0.6857045292854309}, {'Type': 'mouthRight', 'X': 0.5286892652511597, 'Y': 0.6658191680908203}, {'Type': 'leftPupil', 'X': 0.20720601081848145, 'Y': 0.3650256395339966}, {'Type': 'rightPupil', 'X': 0.5372109413146973, 'Y': 0.3467191457748413}, {'Type': 'leftEyeBrowLeft', 'X': 0.07378590852022171, 'Y': 0.24117742478847504}, {'Type': 'leftEyeBrowUp', 'X': 0.17258110642433167, 'Y': 0.1830074042081833}, {'Type': 'leftEyeBrowRight', 'X': 0.2877724766731262, 'Y': 0.20797985792160034}, {'Type': 'rightEyeBrowLeft', 'X': 0.4708024561405182, 'Y': 0.20864041149616241}, {'Type': 'rightEyeBrowUp', 'X': 0.5651643872261047, 'Y': 0.17504122853279114}, {'Type': 'rightEyeBrowRight', 'X': 0.6612844467163086, 'Y': 0.20283907651901245}, {'Type': 'leftEyeLeft', 'X': 0.13776908814907074, 'Y': 0.36383429169654846}, {'Type': 'leftEyeRight', 'X': 0.27700987458229065, 'Y': 0.35906702280044556}, {'Type': 'leftEyeUp', 'X': 0.21130657196044922, 'Y': 0.32815349102020264}, {'Type': 'leftEyeDown', 'X': 0.21011792123317719, 'Y': 0.3825274109840393}, {'Type': 'rightEyeLeft', 'X': 0.4734208881855011, 'Y': 0.3461422324180603}, {'Type': 'rightEyeRight', 'X': 0.6139647960662842, 'Y': 0.33561956882476807}, {'Type': 'rightEyeUp', 'X': 0.5444930791854858, 'Y': 0.31253165006637573}, {'Type': 'rightEyeDown', 'X': 0.5471806526184082, 'Y': 0.3664112687110901}, {'Type': 'noseLeft', 'X': 0.33865639567375183, 'Y': 0.5808728933334351}, {'Type': 'noseRight', 'X': 0.46448177099227905, 'Y': 0.5702013969421387}, {'Type': 'mouthUp', 'X': 0.40595951676368713, 'Y': 0.664688229560852}, {'Type': 'mouthDown', 'X': 0.41318610310554504, 'Y': 0.7226954102516174}], 'Pose': {'Roll': -3.856233596801758, 'Yaw': 5.892911434173584, 'Pitch': -4.012670993804932}, 'Quality': {'Brightness': 35.42747497558594, 'Sharpness': 99.9980239868164}, 'Confidence': 99.99915313720703}]"

# %%
teststring = df['FaceDetails'][15996]

# %%
import json

# %%
json_acceptable_string = teststring.replace("'", "\"")
json_acceptable_string = json_acceptable_string.replace("True", "\"True\"")
json_acceptable_string = json_acceptable_string.replace("False", "\"False\"")
json_acceptable_string = json_acceptable_string[1:-1]

# %%
json_acceptable_string
# Out:
# '{"BoundingBox": {"Width": 1.0099999904632568, "Height": 1.0099999904632568, "Left": -0.17888888716697693, "Top": -0.10444444417953491}, "AgeRange": {"Low": 15, "High": 25}, "Smile": {"Value": "True", "Confidence": 90.81520080566406}, "Eyeglasses": {"Value": "False", "Confidence": 93.44303894042969}, "Sunglasses": {"Value": "False", "Confidence": 99.92829895019531}, "Gender": {"Value": "Female", "Confidence": 100.0}, "Beard": {"Value": "False", "Confidence": 99.99625396728516}, "Mustache": {"Value": "False", "Confidence": 99.999267578125}, "EyesOpen": {"Value": "True", "Confidence": 99.99658203125}, "MouthOpen": {"Value": "False", "Confidence": 99.9348373413086}, "Emotions": [{"Type": "CALM", "Confidence": 58.72126388549805}, {"Type": "HAPPY", "Confidence": 55.22835159301758}, {"Type": "CONFUSED", "Confidence": 3.6207854747772217}], "Landmarks": [{"Type": "eyeLeft", "X": 0.2096046805381775, "Y": 0.35737723112106323}, {"Type": "eyeRight", "X": 0.5451221466064453, "Y": 0.33994126319885254}, {"Type": "nose", "X": 0.4138149917125702, "Y": 0.5268155932426453}, {"Type": "mouthLeft", "X": 0.2641378939151764, "Y": 0.6857045292854309}, {"Type": "mouthRight", "X": 0.5286892652511597, "Y": 0.6658191680908203}, {"Type": "leftPupil", "X": 0.20720601081848145, "Y": 0.3650256395339966}, {"Type": "rightPupil", "X": 0.5372109413146973, "Y": 0.3467191457748413}, {"Type": "leftEyeBrowLeft", "X": 0.07378590852022171, "Y": 0.24117742478847504}, {"Type": "leftEyeBrowUp", "X": 0.17258110642433167, "Y": 0.1830074042081833}, {"Type": "leftEyeBrowRight", "X": 0.2877724766731262, "Y": 0.20797985792160034}, {"Type": "rightEyeBrowLeft", "X": 0.4708024561405182, "Y": 0.20864041149616241}, {"Type": "rightEyeBrowUp", "X": 0.5651643872261047, "Y": 0.17504122853279114}, {"Type": "rightEyeBrowRight", "X": 0.6612844467163086, "Y": 0.20283907651901245}, {"Type": "leftEyeLeft", "X": 0.13776908814907074, "Y": 0.36383429169654846}, {"Type": "leftEyeRight", "X": 0.27700987458229065, "Y": 0.35906702280044556}, {"Type": "leftEyeUp", "X": 0.21130657196044922, "Y": 0.32815349102020264}, {"Type": "leftEyeDown", "X": 0.21011792123317719, "Y": 0.3825274109840393}, {"Type": "rightEyeLeft", "X": 0.4734208881855011, "Y": 0.3461422324180603}, {"Type": "rightEyeRight", "X": 0.6139647960662842, "Y": 0.33561956882476807}, {"Type": "rightEyeUp", "X": 0.5444930791854858, "Y": 0.31253165006637573}, {"Type": "rightEyeDown", "X": 0.5471806526184082, "Y": 0.3664112687110901}, {"Type": "noseLeft", "X": 0.33865639567375183, "Y": 0.5808728933334351}, {"Type": "noseRight", "X": 0.46448177099227905, "Y": 0.5702013969421387}, {"Type": "mouthUp", "X": 0.40595951676368713, "Y": 0.664688229560852}, {"Type": "mouthDown", "X": 0.41318610310554504, "Y": 0.7226954102516174}], "Pose": {"Roll": -3.856233596801758, "Yaw": 5.892911434173584, "Pitch": -4.012670993804932}, "Quality": {"Brightness": 35.42747497558594, "Sharpness": 99.9980239868164}, "Confidence": 99.99915313720703}'

# %%
d = json.loads(json_acceptable_string)

# %%
d
# Out:
# {'AgeRange': {'High': 25, 'Low': 15},
#  'Beard': {'Confidence': 99.99625396728516, 'Value': 'False'},
#  'BoundingBox': {'Height': 1.0099999904632568,
#   'Left': -0.17888888716697693,
#   'Top': -0.10444444417953491,
#   'Width': 1.0099999904632568},
#  'Confidence': 99.99915313720703,
#  'Emotions': [{'Confidence': 58.72126388549805, 'Type': 'CALM'},
#   {'Confidence': 55.22835159301758, 'Type': 'HAPPY'},
#   {'Confidence': 3.6207854747772217, 'Type': 'CONFUSED'}],
#  'Eyeglasses': {'Confidence': 93.44303894042969, 'Value': 'False'},
#  'EyesOpen': {'Confidence': 99.99658203125, 'Value': 'True'},
#  'Gender': {'Confidence': 100.0, 'Value': 'Female'},
#  'Landmarks': [{'Type': 'eyeLeft',
#    'X': 0.2096046805381775,
#    'Y': 0.35737723112106323},
#   {'Type': 'eyeRight', 'X': 0.5451221466064453, 'Y': 0.33994126319885254},
#   {'Type': 'nose', 'X': 0.4138149917125702, 'Y': 0.5268155932426453},
#   {'Type': 'mouthLeft', 'X': 0.2641378939151764, 'Y': 0.6857045292854309},
#   {'Type': 'mouthRight', 'X': 0.5286892652511597, 'Y': 0.6658191680908203},
#   {'Type': 'leftPupil', 'X': 0.20720601081848145, 'Y': 0.3650256395339966},
#   {'Type': 'rightPupil', 'X': 0.5372109413146973, 'Y': 0.3467191457748413},
#   {'Type': 'leftEyeBrowLeft',
#    'X': 0.07378590852022171,
#    'Y': 0.24117742478847504},
#   {'Type': 'leftEyeBrowUp', 'X': 0.17258110642433167, 'Y': 0.1830074042081833},
#   {'Type': 'leftEyeBrowRight',
#    'X': 0.2877724766731262,
#    'Y': 0.20797985792160034},
#   {'Type': 'rightEyeBrowLeft',
#    'X': 0.4708024561405182,
#    'Y': 0.20864041149616241},
#   {'Type': 'rightEyeBrowUp',
#    'X': 0.5651643872261047,
#    'Y': 0.17504122853279114},
#   {'Type': 'rightEyeBrowRight',
#    'X': 0.6612844467163086,
#    'Y': 0.20283907651901245},
#   {'Type': 'leftEyeLeft', 'X': 0.13776908814907074, 'Y': 0.36383429169654846},
#   {'Type': 'leftEyeRight', 'X': 0.27700987458229065, 'Y': 0.35906702280044556},
#   {'Type': 'leftEyeUp', 'X': 0.21130657196044922, 'Y': 0.32815349102020264},
#   {'Type': 'leftEyeDown', 'X': 0.21011792123317719, 'Y': 0.3825274109840393},
#   {'Type': 'rightEyeLeft', 'X': 0.4734208881855011, 'Y': 0.3461422324180603},
#   {'Type': 'rightEyeRight', 'X': 0.6139647960662842, 'Y': 0.33561956882476807},
#   {'Type': 'rightEyeUp', 'X': 0.5444930791854858, 'Y': 0.31253165006637573},
#   {'Type': 'rightEyeDown', 'X': 0.5471806526184082, 'Y': 0.3664112687110901},
#   {'Type': 'noseLeft', 'X': 0.33865639567375183, 'Y': 0.5808728933334351},
#   {'Type': 'noseRight', 'X': 0.46448177099227905, 'Y': 0.5702013969421387},
#   {'Type': 'mouthUp', 'X': 0.40595951676368713, 'Y': 0.664688229560852},
#   {'Type': 'mouthDown', 'X': 0.41318610310554504, 'Y': 0.7226954102516174}],
#  'MouthOpen': {'Confidence': 99.9348373413086, 'Value': 'False'},
#  'Mustache': {'Confidence': 99.999267578125, 'Value': 'False'},
#  'Pose': {'Pitch': -4.012670993804932,
#   'Roll': -3.856233596801758,
#   'Yaw': 5.892911434173584},
#  'Quality': {'Brightness': 35.42747497558594, 'Sharpness': 99.9980239868164},
#  'Smile': {'Confidence': 90.81520080566406, 'Value': 'True'},
#  'Sunglasses': {'Confidence': 99.92829895019531, 'Value': 'False'}}

# %%
len(d)
# Out:
# 15

# %%
d.keys()
# Out:
# dict_keys(['BoundingBox', 'AgeRange', 'Smile', 'Eyeglasses', 'Sunglasses', 'Gender', 'Beard', 'Mustache', 'EyesOpen', 'MouthOpen', 'Emotions', 'Landmarks', 'Pose', 'Quality', 'Confidence'])

# %%
d['AgeRange']
# Out:
# {'High': 25, 'Low': 15}

# %%
d['Smile']
# Out:
# {'Confidence': 90.81520080566406, 'Value': 'True'}

# %%
d['Eyeglasses']
# Out:
# {'Confidence': 93.44303894042969, 'Value': 'False'}

# %%
d['Sunglasses']
# Out:
# {'Confidence': 99.92829895019531, 'Value': 'False'}

# %%
d['Gender']
# Out:
# {'Confidence': 100.0, 'Value': 'Female'}

# %%
d['Beard']
# Out:
# {'Confidence': 99.99625396728516, 'Value': 'False'}

# %%
d['Mustache']
# Out:
# {'Confidence': 99.999267578125, 'Value': 'False'}

# %%
d['EyesOpen']
# Out:
# {'Confidence': 99.99658203125, 'Value': 'True'}

# %%
d['MouthOpen']
# Out:
# {'Confidence': 99.9348373413086, 'Value': 'False'}

# %%
d['Emotions']
# Out:
# [{'Confidence': 58.72126388549805, 'Type': 'CALM'},
#  {'Confidence': 55.22835159301758, 'Type': 'HAPPY'},
#  {'Confidence': 3.6207854747772217, 'Type': 'CONFUSED'}]

# %%
d['Pose']
# Out:
# {'Pitch': -4.012670993804932,
#  'Roll': -3.856233596801758,
#  'Yaw': 5.892911434173584}

# %%
d['Quality']
# Out:
# {'Brightness': 35.42747497558594, 'Sharpness': 99.9980239868164}

# %%
d['Confidence']
# Out:
# 99.99915313720703

# %%
QualityDF = pd.DataFrame(data=d['Quality'], index=[0])
QualityDF
# Out:
#    Brightness  Sharpness
# 0   35.427475  99.998024

# %%
d['Smile'].keys()
# Out:
# dict_keys(['Value', 'Confidence'])

# %%
d['Smile']['Confidence']
# Out:
# 90.81520080566406

# %%
d['Gender']
# Out:
# {'Confidence': 100.0, 'Value': 'Female'}

# %%
d['Gender']['Value']
# Out:
# 'Female'

# %%
d['Beard']
# Out:
# {'Confidence': 99.99625396728516, 'Value': 'False'}

# %%
d['Mustache']
# Out:
# {'Confidence': 99.999267578125, 'Value': 'False'}

# %%
d['EyesOpen']
# Out:
# {'Confidence': 99.99658203125, 'Value': 'True'}

# %%
d['MouthOpen']
# Out:
# {'Confidence': 99.9348373413086, 'Value': 'False'}

# %%
d['Emotions']
# Out:
# [{'Confidence': 58.72126388549805, 'Type': 'CALM'},
#  {'Confidence': 55.22835159301758, 'Type': 'HAPPY'},
#  {'Confidence': 3.6207854747772217, 'Type': 'CONFUSED'}]

# %%
d['Emotions'][0]
# Out:
# {'Confidence': 58.72126388549805, 'Type': 'CALM'}

# %% [markdown]
# ### write a function to extract features

# %%
def get_emotion(string):
    """input face detail string, output list of emotion types"""
    # change the string to json acceptable format
    json_string = string.replace("'", "\"")
    json_string = json_string.replace("True", "\"True\"")
    json_string = json_string.replace("False", "\"False\"")
    json_string = json_string[1:-1]
    
    # convert to python object
    d = json.loads(json_string)
    
    # get emotions
    EmotionList = []
    for i in d['Emotions']:
        EmotionList.append(i['Type'])
        
    return EmotionList

# %%
df['FaceDetails'][5][2580:2650]
# Out:
# "76599}, {'Type': 'mouthUp', 'X': 0.36307042837142944, 'Y': 0.648285090"

# %%
get_emotion(df['FaceDetails'][5])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-83-932986ff4df3> in <module>()
# ----> 1 get_emotion(df['FaceDetails'][5])
#
# <ipython-input-74-45576d19414c> in get_emotion(string)
#       8
#       9     # convert to python object
# ---> 10     d = json.loads(json_string)
#      11
#      12     # get emotions
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 1 column 2952 (char 2951)

# %%
for i in range(len(df['FaceDetails'])):
    EmotionList = get_emotion(df['FaceDetails'][i])
    print(i, 'is done.')
    EmotionSet = set()
    for emotion in EmotionList:
        EmotionSet.add(emotion)

EmotionSet
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-76-44fbfdf38250> in <module>()
#       1 for i in range(len(df['FaceDetails'])):
# ----> 2     EmotionList = get_emotion(df['FaceDetails'][i])
#       3     print(i, 'is done.')
#       4     EmotionSet = set()
#       5     for emotion in EmotionList:
#
# <ipython-input-74-45576d19414c> in get_emotion(string)
#       8
#       9     # convert to python object
# ---> 10     d = json.loads(json_string)
#      11
#      12     # get emotions
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 1 column 2944 (char 2943)

# %%
SmileList = []
GenderList = []
BeardList = []
MustacheList = []
EyesOpenList = []
MouthOpenList = []

# %%
for string in df['FaceDetails']:
    # change the string to json acceptable format
    json_string = string.replace("'", "\"")
    json_string = json_string.replace("True", "\"True\"")
    json_string = json_string.replace("False", "\"False\"")
    json_string = json_string[1:-1]
    
    # convert to python object
    d = json.loads(json_string)
    
    # add value to list
    SmileList.append(d['Smile']['Confidence'])
    GenderList.append(d['Gender']['Value'])
    BeardList.append(d['Beard']['Value'])
    MustacheList.append(d['Mustache']['Value'])
    EyesOpenList.append(d['EyesOpen']['Value'])
    MouthOpenList.append(d['MouthOpen']['Value'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-93-fdf77eb6c575> in <module>()
#       7
#       8     # convert to python object
# ----> 9     d = json.loads(json_string)
#      10
#      11     # add value to list
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 1 column 2944 (char 2943)

# %%
GenderList
# Out:
# []
