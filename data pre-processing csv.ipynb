# %%
import numpy as np
import pandas as pd
import glob
import json

# %% [markdown]
# ## Data Pre-processing

# %%
# read in csv file generated by Amazon API
path = r'C:\Users\movin\Documents\GitHub\PersonalityFromPhoto\data'
allFiles = glob.glob(path + '/*.csv')
df = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_, index_col=None, header=0)
    list_.append(df)
df = pd.concat(list_, ignore_index=True)

# %%
len(df.index)
# Out:
# 15997

# %%
df.head()
# Out:
#    Unnamed: 0                             fileName  \
# 0           0   Facebook/ENFJ/1000006876806379.jpg
# 1           1   Facebook/ENFJ/1001091583356351.jpg
# 2           2   Facebook/ENFJ/1001328126675771.jpg
# 3           3  Facebook/ENFJ/10100163853254202.jpg
# 4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...
# 1                                                 []
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...
# 3                                                 []
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...

# %%
# rename the unnamed column
df = df.rename(columns={'Unnamed: 0': 'GroupIndex'})

# %%
# add an index column
df['index'] = np.arange(len(df.index))

# %%
cols = df.columns.tolist()
cols
# Out:
# ['GroupIndex', 'fileName', 'Labels', 'FaceDetails', 'index']

# %%
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['index', 'GroupIndex', 'fileName', 'Labels', 'FaceDetails']

# %%
df = df[cols]

# %%
df.head()
# Out:
#    index  GroupIndex                             fileName  \
# 0      0           0   Facebook/ENFJ/1000006876806379.jpg
# 1      1           1   Facebook/ENFJ/1001091583356351.jpg
# 2      2           2   Facebook/ENFJ/1001328126675771.jpg
# 3      3           3  Facebook/ENFJ/10100163853254202.jpg
# 4      4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...
# 1                                                 []
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...
# 3                                                 []
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...

# %%
# get the personality for every photo
# get photo name as fileName

personality_list = []
photoName_list = []

for i in range(len(df.index)):
    personality_list.append(df['fileName'][i][9:13])
    photoName_list.append(df['fileName'][i][14:])

# %%
len(personality_list)
# Out:
# 15997

# %%
len(photoName_list)
# Out:
# 15997

# %%
# add the personality column to dataframe
se = pd.Series(personality_list)
df['Personality'] = se.values
df.head()
# Out:
#    index  GroupIndex                             fileName  \
# 0      0           0   Facebook/ENFJ/1000006876806379.jpg
# 1      1           1   Facebook/ENFJ/1001091583356351.jpg
# 2      2           2   Facebook/ENFJ/1001328126675771.jpg
# 3      3           3  Facebook/ENFJ/10100163853254202.jpg
# 4      4           4  Facebook/ENFJ/10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                 []        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                 []        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ

# %%
# drop the fileName column

df = df.drop(['fileName'], axis=1)
df.head()
# Out:
#    index  GroupIndex                                             Labels  \
# 0      0           0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1      1           1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2      2           2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3      3           3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4      4           4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                 []        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                 []        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ

# %%
# add PhotoName column

se = pd.Series(photoName_list)
df['PhotoName'] = se.values
df.head()
# Out:
#    index  GroupIndex                                             Labels  \
# 0      0           0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1      1           1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2      2           2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3      3           3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4      4           4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality  \
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                 []        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                 []        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ
#
#                PhotoName
# 0   1000006876806379.jpg
# 1   1001091583356351.jpg
# 2   1001328126675771.jpg
# 3  10100163853254202.jpg
# 4  10100238407492499.jpg

# %%
cols = df.columns.tolist()
cols
# Out:
# ['index', 'GroupIndex', 'Labels', 'FaceDetails', 'Personality', 'PhotoName']

# %%
cols = cols[0:2] + cols[-1:] + cols[2:5]
cols
# Out:
# ['index', 'GroupIndex', 'PhotoName', 'Labels', 'FaceDetails', 'Personality']

# %%
df = df[cols]
df.head()
# Out:
#    index  GroupIndex              PhotoName  \
# 0      0           0   1000006876806379.jpg
# 1      1           1   1001091583356351.jpg
# 2      2           2   1001328126675771.jpg
# 3      3           3  10100163853254202.jpg
# 4      4           4  10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                 []        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                 []        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ

# %%
# empty face details number
count = 0
for i in df['FaceDetails']:
    if len(i)==2:
        count += 1

# %%
# 3409 photo don't have face details returned
count
# Out:
# 3409

# %%
# replace empty face detail with NaN
df = df.replace('[]', np.nan)

# %%
df.head()
# Out:
#    index  GroupIndex              PhotoName  \
# 0      0           0   1000006876806379.jpg
# 1      1           1   1001091583356351.jpg
# 2      2           2   1001328126675771.jpg
# 3      3           3  10100163853254202.jpg
# 4      4           4  10100238407492499.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 1  [{'Name': 'Art', 'Confidence': 52.856147766113...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 3  [{'Name': 'Art', 'Confidence': 91.370552062988...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 1                                                NaN        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 3                                                NaN        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ

# %%
# drop empty value
df = df.dropna()

# %%
df.head()
# Out:
#    index  GroupIndex              PhotoName  \
# 0      0           0   1000006876806379.jpg
# 2      2           2   1001328126675771.jpg
# 4      4           4  10100238407492499.jpg
# 5      5           5  10100251167240940.jpg
# 6      6           6  10100259363675182.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
# 5  [{'Name': 'People', 'Confidence': 99.175323486...
# 6  [{'Name': 'Human', 'Confidence': 99.2900848388...
#
#                                          FaceDetails Personality
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ
# 5  [{'BoundingBox': {'Width': 0.12111110985279083...        ENFJ
# 6  [{'BoundingBox': {'Width': 0.42888888716697693...        ENFJ

# %%
len(df)
# Out:
# 12580

# %%
# separate the personality type to IvsE, SvsN, TvsF, JvsP
IvsE_list = []
SvsN_list = []
TvsF_list = []
JvsP_list = []

for i in df['Personality']:
    if i == 'ENFJ':
        IvsE_list.append('E')
        SvsN_list.append('N')
        TvsF_list.append('Feel')
        JvsP_list.append('J')
    elif i == 'ENFP':
        IvsE_list.append('E')
        SvsN_list.append('N')
        TvsF_list.append('Feel')
        JvsP_list.append('P')
    elif i == 'ENTJ':
        IvsE_list.append('E')
        SvsN_list.append('N')
        TvsF_list.append('Think')
        JvsP_list.append('J')
    elif i == 'ENTP':
        IvsE_list.append('E')
        SvsN_list.append('N')
        TvsF_list.append('Think')
        JvsP_list.append('P')
    elif i == 'ESFJ':
        IvsE_list.append('E')
        SvsN_list.append('S')
        TvsF_list.append('Feel')
        JvsP_list.append('J')
    elif i == 'ESFP':
        IvsE_list.append('E')
        SvsN_list.append('S')
        TvsF_list.append('Feel')
        JvsP_list.append('P')
    elif i == 'ESTJ':
        IvsE_list.append('E')
        SvsN_list.append('S')
        TvsF_list.append('Think')
        JvsP_list.append('J')
    elif i == 'ESTP':
        IvsE_list.append('E')
        SvsN_list.append('S')
        TvsF_list.append('Think')
        JvsP_list.append('P')
    elif i == 'INFJ':
        IvsE_list.append('I')
        SvsN_list.append('N')
        TvsF_list.append('Feel')
        JvsP_list.append('J')
    elif i == 'INFP':
        IvsE_list.append('I')
        SvsN_list.append('N')
        TvsF_list.append('Feel')
        JvsP_list.append('P')
    elif i == 'INTJ':
        IvsE_list.append('I')
        SvsN_list.append('N')
        TvsF_list.append('Think')
        JvsP_list.append('J')
    elif i == 'INTP':
        IvsE_list.append('I')
        SvsN_list.append('N')
        TvsF_list.append('Think')
        JvsP_list.append('P')
    elif i == 'ISFJ':
        IvsE_list.append('I')
        SvsN_list.append('S')
        TvsF_list.append('Feel')
        JvsP_list.append('J')
    elif i == 'ISFP':
        IvsE_list.append('I')
        SvsN_list.append('S')
        TvsF_list.append('Feel')
        JvsP_list.append('P')
    elif i == 'ISTJ':
        IvsE_list.append('I')
        SvsN_list.append('S')
        TvsF_list.append('Think')
        JvsP_list.append('J')
    elif i == 'ISTP':
        IvsE_list.append('I')
        SvsN_list.append('S')
        TvsF_list.append('Think')
        JvsP_list.append('P')
    else:
        print('None of the 16 types.')

# %%
df['IvsE'] = IvsE_list
df['SvsN'] = SvsN_list
df['TvsF'] = TvsF_list
df['JvsP'] = JvsP_list

df.head()
# Out:
#    index  GroupIndex              PhotoName  \
# 0      0           0   1000006876806379.jpg
# 2      2           2   1001328126675771.jpg
# 4      4           4  10100238407492499.jpg
# 5      5           5  10100251167240940.jpg
# 6      6           6  10100259363675182.jpg
#
#                                               Labels  \
# 0  [{'Name': 'Human', 'Confidence': 99.2957839965...
# 2  [{'Name': 'People', 'Confidence': 99.012985229...
# 4  [{'Name': 'Human', 'Confidence': 99.3081130981...
# 5  [{'Name': 'People', 'Confidence': 99.175323486...
# 6  [{'Name': 'Human', 'Confidence': 99.2900848388...
#
#                                          FaceDetails Personality IvsE SvsN  \
# 0  [{'BoundingBox': {'Width': 0.11999999731779099...        ENFJ    E    N
# 2  [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ    E    N
# 4  [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ    E    N
# 5  [{'BoundingBox': {'Width': 0.12111110985279083...        ENFJ    E    N
# 6  [{'BoundingBox': {'Width': 0.42888888716697693...        ENFJ    E    N
#
#    TvsF JvsP
# 0  Feel    J
# 2  Feel    J
# 4  Feel    J
# 5  Feel    J
# 6  Feel    J

# %% [markdown]
# ## Face Detail Value

# %%
df['FaceDetails'][2]
# Out:
# "[{'BoundingBox': {'Width': 0.4146634638309479, 'Height': 0.4146634638309479, 'Left': 0.05288461595773697, 'Top': 0.25961539149284363}, 'AgeRange': {'Low': 19, 'High': 36}, 'Smile': {'Value': True, 'Confidence': 62.861515045166016}, 'Eyeglasses': {'Value': False, 'Confidence': 99.99372100830078}, 'Sunglasses': {'Value': False, 'Confidence': 99.97441101074219}, 'Gender': {'Value': 'Female', 'Confidence': 100.0}, 'Beard': {'Value': True, 'Confidence': 52.13731384277344}, 'Mustache': {'Value': False, 'Confidence': 81.03985595703125}, 'EyesOpen': {'Value': True, 'Confidence': 99.98633575439453}, 'MouthOpen': {'Value': False, 'Confidence': 99.98002624511719}, 'Emotions': [{'Type': 'HAPPY', 'Confidence': 86.62401580810547}, {'Type': 'CONFUSED', 'Confidence': 1.4656126499176025}, {'Type': 'CALM', 'Confidence': 1.3178050518035889}], 'Landmarks': [{'Type': 'eyeLeft', 'X': 0.1717977076768875, 'Y': 0.43629008531570435}, {'Type': 'eyeRight', 'X': 0.3249512314796448, 'Y': 0.4205191731452942}, {'Type': 'nose', 'X': 0.24751560389995575, 'Y': 0.5103107690811157}, {'Type': 'mouthLeft', 'X': 0.21099551022052765, 'Y': 0.574430525302887}, {'Type': 'mouthRight', 'X': 0.3355630934238434, 'Y': 0.55283522605896}, {'Type': 'leftPupil', 'X': 0.16932371258735657, 'Y': 0.4329424798488617}, {'Type': 'rightPupil', 'X': 0.32163870334625244, 'Y': 0.417344868183136}, {'Type': 'leftEyeBrowLeft', 'X': 0.1056876927614212, 'Y': 0.39211729168891907}, {'Type': 'leftEyeBrowUp', 'X': 0.14720669388771057, 'Y': 0.37380319833755493}, {'Type': 'leftEyeBrowRight', 'X': 0.19443607330322266, 'Y': 0.37836214900016785}, {'Type': 'rightEyeBrowLeft', 'X': 0.27868959307670593, 'Y': 0.3719310760498047}, {'Type': 'rightEyeBrowUp', 'X': 0.3320518136024475, 'Y': 0.3593292832374573}, {'Type': 'rightEyeBrowRight', 'X': 0.3794845938682556, 'Y': 0.37503287196159363}, {'Type': 'leftEyeLeft', 'X': 0.1436019241809845, 'Y': 0.43918341398239136}, {'Type': 'leftEyeRight', 'X': 0.20330579578876495, 'Y': 0.43627604842185974}, {'Type': 'leftEyeUp', 'X': 0.16949866712093353, 'Y': 0.42496341466903687}, {'Type': 'leftEyeDown', 'X': 0.17244060337543488, 'Y': 0.44617700576782227}, {'Type': 'rightEyeLeft', 'X': 0.29562288522720337, 'Y': 0.42770805954933167}, {'Type': 'rightEyeRight', 'X': 0.35583463311195374, 'Y': 0.41822299361228943}, {'Type': 'rightEyeUp', 'X': 0.3224487006664276, 'Y': 0.4088370203971863}, {'Type': 'rightEyeDown', 'X': 0.3266761600971222, 'Y': 0.42975497245788574}, {'Type': 'noseLeft', 'X': 0.23016862571239471, 'Y': 0.5311914682388306}, {'Type': 'noseRight', 'X': 0.28940901160240173, 'Y': 0.5214301347732544}, {'Type': 'mouthUp', 'X': 0.27023857831954956, 'Y': 0.5574645400047302}, {'Type': 'mouthDown', 'X': 0.2754146158695221, 'Y': 0.588654100894928}], 'Pose': {'Roll': -5.676806926727295, 'Yaw': -9.280488014221191, 'Pitch': -8.956658363342285}, 'Quality': {'Brightness': 38.64361572265625, 'Sharpness': 99.9980239868164}, 'Confidence': 99.99908447265625}]"

# %%
teststring = df['FaceDetails'][2]

# %%
import ast

# %%
dictstring = teststring[1:-1]
testdict = ast.literal_eval(dictstring)

# %%
testdict
# Out:
# {'AgeRange': {'High': 36, 'Low': 19},
#  'Beard': {'Confidence': 52.13731384277344, 'Value': True},
#  'BoundingBox': {'Height': 0.4146634638309479,
#   'Left': 0.05288461595773697,
#   'Top': 0.25961539149284363,
#   'Width': 0.4146634638309479},
#  'Confidence': 99.99908447265625,
#  'Emotions': [{'Confidence': 86.62401580810547, 'Type': 'HAPPY'},
#   {'Confidence': 1.4656126499176025, 'Type': 'CONFUSED'},
#   {'Confidence': 1.3178050518035889, 'Type': 'CALM'}],
#  'Eyeglasses': {'Confidence': 99.99372100830078, 'Value': False},
#  'EyesOpen': {'Confidence': 99.98633575439453, 'Value': True},
#  'Gender': {'Confidence': 100.0, 'Value': 'Female'},
#  'Landmarks': [{'Type': 'eyeLeft',
#    'X': 0.1717977076768875,
#    'Y': 0.43629008531570435},
#   {'Type': 'eyeRight', 'X': 0.3249512314796448, 'Y': 0.4205191731452942},
#   {'Type': 'nose', 'X': 0.24751560389995575, 'Y': 0.5103107690811157},
#   {'Type': 'mouthLeft', 'X': 0.21099551022052765, 'Y': 0.574430525302887},
#   {'Type': 'mouthRight', 'X': 0.3355630934238434, 'Y': 0.55283522605896},
#   {'Type': 'leftPupil', 'X': 0.16932371258735657, 'Y': 0.4329424798488617},
#   {'Type': 'rightPupil', 'X': 0.32163870334625244, 'Y': 0.417344868183136},
#   {'Type': 'leftEyeBrowLeft',
#    'X': 0.1056876927614212,
#    'Y': 0.39211729168891907},
#   {'Type': 'leftEyeBrowUp',
#    'X': 0.14720669388771057,
#    'Y': 0.37380319833755493},
#   {'Type': 'leftEyeBrowRight',
#    'X': 0.19443607330322266,
#    'Y': 0.37836214900016785},
#   {'Type': 'rightEyeBrowLeft',
#    'X': 0.27868959307670593,
#    'Y': 0.3719310760498047},
#   {'Type': 'rightEyeBrowUp', 'X': 0.3320518136024475, 'Y': 0.3593292832374573},
#   {'Type': 'rightEyeBrowRight',
#    'X': 0.3794845938682556,
#    'Y': 0.37503287196159363},
#   {'Type': 'leftEyeLeft', 'X': 0.1436019241809845, 'Y': 0.43918341398239136},
#   {'Type': 'leftEyeRight', 'X': 0.20330579578876495, 'Y': 0.43627604842185974},
#   {'Type': 'leftEyeUp', 'X': 0.16949866712093353, 'Y': 0.42496341466903687},
#   {'Type': 'leftEyeDown', 'X': 0.17244060337543488, 'Y': 0.44617700576782227},
#   {'Type': 'rightEyeLeft', 'X': 0.29562288522720337, 'Y': 0.42770805954933167},
#   {'Type': 'rightEyeRight',
#    'X': 0.35583463311195374,
#    'Y': 0.41822299361228943},
#   {'Type': 'rightEyeUp', 'X': 0.3224487006664276, 'Y': 0.4088370203971863},
#   {'Type': 'rightEyeDown', 'X': 0.3266761600971222, 'Y': 0.42975497245788574},
#   {'Type': 'noseLeft', 'X': 0.23016862571239471, 'Y': 0.5311914682388306},
#   {'Type': 'noseRight', 'X': 0.28940901160240173, 'Y': 0.5214301347732544},
#   {'Type': 'mouthUp', 'X': 0.27023857831954956, 'Y': 0.5574645400047302},
#   {'Type': 'mouthDown', 'X': 0.2754146158695221, 'Y': 0.588654100894928}],
#  'MouthOpen': {'Confidence': 99.98002624511719, 'Value': False},
#  'Mustache': {'Confidence': 81.03985595703125, 'Value': False},
#  'Pose': {'Pitch': -8.956658363342285,
#   'Roll': -5.676806926727295,
#   'Yaw': -9.280488014221191},
#  'Quality': {'Brightness': 38.64361572265625, 'Sharpness': 99.9980239868164},
#  'Smile': {'Confidence': 62.861515045166016, 'Value': True},
#  'Sunglasses': {'Confidence': 99.97441101074219, 'Value': False}}

# %%
testdict['Quality']['Brightness']
# Out:
# 38.64361572265625

# %%
testdict.keys()
# Out:
# dict_keys(['BoundingBox', 'AgeRange', 'Smile', 'Eyeglasses', 'Sunglasses', 'Gender', 'Beard', 'Mustache', 'EyesOpen', 'MouthOpen', 'Emotions', 'Landmarks', 'Pose', 'Quality', 'Confidence'])

# %%
len(testdict)
# Out:
# 15

# %%
testdict['AgeRange']
# Out:
# {'High': 36, 'Low': 19}

# %%
testdict['Smile']
# Out:
# {'Confidence': 62.861515045166016, 'Value': True}

# %%
testdict['Eyeglasses']
# Out:
# {'Confidence': 99.99372100830078, 'Value': False}

# %%
testdict['Sunglasses']
# Out:
# {'Confidence': 99.97441101074219, 'Value': False}

# %%
testdict['Gender']
# Out:
# {'Confidence': 100.0, 'Value': 'Female'}

# %%
testdict['Beard']
# Out:
# {'Confidence': 52.13731384277344, 'Value': True}

# %%
testdict['Mustache']
# Out:
# {'Confidence': 81.03985595703125, 'Value': False}

# %%
testdict['EyesOpen']
# Out:
# {'Confidence': 99.98633575439453, 'Value': True}

# %%
testdict['MouthOpen']
# Out:
# {'Confidence': 99.98002624511719, 'Value': False}

# %%
testdict['Emotions']
# Out:
# [{'Confidence': 86.62401580810547, 'Type': 'HAPPY'},
#  {'Confidence': 1.4656126499176025, 'Type': 'CONFUSED'},
#  {'Confidence': 1.3178050518035889, 'Type': 'CALM'}]

# %%
testdict['Pose']
# Out:
# {'Pitch': -8.956658363342285,
#  'Roll': -5.676806926727295,
#  'Yaw': -9.280488014221191}

# %%
testdict['Quality']
# Out:
# {'Brightness': 38.64361572265625, 'Sharpness': 99.9980239868164}

# %%
testdict['Confidence']
# Out:
# 99.99908447265625

# %%
QualityDF = pd.DataFrame(data=testdict['Quality'], index=[0])
QualityDF
# Out:
#    Brightness  Sharpness
# 0   38.643616  99.998024

# %% [markdown]
# ### some photos have multiple people

# %%
# get all emotion types
for face_str in df['FaceDetails']:
    # delete [] of string
    face_str = face_str[1:-1]
    
    # convert to dict
    face_dict = ast.literal_eval(face_str)
    
    # see if every observation has 3 emotion types
    count = 0
    if len(face_dict['Emotions']) != 3:
        count += 1
    
    # get emotions
    EmotionSet = set()
    for i in face_dict['Emotions']:
        EmotionSet.add(i['Type'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-425d9287b71d> in <module>()
#       9     # see if every observation has 3 emotion types
#      10     count = 0
# ---> 11     if len(face_dict['Emotions']) != 3:
#      12         count += 1
#      13
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# only three tyeps of emotions
EmotionSet
# Out:
# {'CALM', 'CONFUSED', 'HAPPY'}

# %%
# every observation has those three types of emotions
count
# Out:
# 0

# %%
# get all pose types
for face_str in df['FaceDetails']:
    # delete [] of string
    face_str = face_str[1:-1]
    
    # convert to dict
    face_dict = ast.literal_eval(face_str)
    
    # see if every observation has 3 emotion types
    count = 0
    if len(face_dict['Pose']) != 3:
        count += 1
    
    # get emotions
    PoseSet = set()
    for i in list(face_dict['Pose'].keys()):
        PoseSet.add(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-0692253353c9> in <module>()
#       9     # see if every observation has 3 emotion types
#      10     count = 0
# ---> 11     if len(face_dict['Pose']) != 3:
#      12         count += 1
#      13
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# only those three types of poses
PoseSet
# Out:
# {'Pitch', 'Roll', 'Yaw'}

# %%
# every observation has three poses
count
# Out:
# 0

# %%
# only keep photos of one person

drop_index = []
for i in range(len(df)):
    # check string length, <3000 is one person
    if len(df['FaceDetails'].iloc[i]) > 3000:
        drop_index.append(df.index[i])

# %%
df = df.drop(drop_index)

# %%
len(df)
# Out:
# 9525

# %%
df.head()
# Out:
#     index  GroupIndex              PhotoName  \
# 2       2           2   1001328126675771.jpg
# 4       4           4  10100238407492499.jpg
# 7       7           7  10100279131750930.jpg
# 9       9           9  10100367881175131.jpg
# 10     10          10  10100371498945180.jpg
#
#                                                Labels  \
# 2   [{'Name': 'People', 'Confidence': 99.012985229...
# 4   [{'Name': 'Human', 'Confidence': 99.3081130981...
# 7   [{'Name': 'People', 'Confidence': 98.705482482...
# 9   [{'Name': 'Human', 'Confidence': 99.3036804199...
# 10  [{'Name': 'Human', 'Confidence': 99.3256072998...
#
#                                           FaceDetails Personality IvsE SvsN  \
# 2   [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ    E    N
# 4   [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ    E    N
# 7   [{'BoundingBox': {'Width': 0.6666666865348816,...        ENFJ    E    N
# 9   [{'BoundingBox': {'Width': 0.39759817719459534...        ENFJ    E    N
# 10  [{'BoundingBox': {'Width': 0.4933333396911621,...        ENFJ    E    N
#
#     TvsF JvsP
# 2   Feel    J
# 4   Feel    J
# 7   Feel    J
# 9   Feel    J
# 10  Feel    J

# %%
testdict['Emotions']
# Out:
# [{'Confidence': 86.62401580810547, 'Type': 'HAPPY'},
#  {'Confidence': 1.4656126499176025, 'Type': 'CONFUSED'},
#  {'Confidence': 1.3178050518035889, 'Type': 'CALM'}]

# %%
EmotionsList = []
for i in testdict['Emotions']:
    EmotionsList.append(i['Type'])
EmotionsList
# Out:
# ['HAPPY', 'CONFUSED', 'CALM']

# %%
'HAPPY' in EmotionsList
# Out:
# True

# %%
EmotionIndex = EmotionsList.index('HAPPY')
EmotionIndex
# Out:
# 0

# %%
testdict['Emotions'][EmotionIndex]
# Out:
# {'Confidence': 86.62401580810547, 'Type': 'HAPPY'}

# %%
# get features

AgeList = []

BeardConfList = []
BeardValueList = []

HappyList = []
ConfusedList = []
CalmList = []
AngryList = []
SadList = []
SurprisedList = []
DisgustedList = []

EyeglassesConfList = []
EyeglassesValueList = []

EyesOpenConfList = []
EyesOpenValueList = []

GenderConfList = []
GenderValueList = []

MouthOpenConfList = []
MouthOpenValueList = []

MustacheConfList = []
MustacheValueList = []

PitchList = []
RollList = []
YawList = []

SmileConfList = []
SmileValueList = []

BrightnessList = []
SharpnessList = []

SunglassesConfList = []
SunglassesValueList = []

for face_str in df['FaceDetails']:
    # delete [] of string
    face_str = face_str[1:-1]
    
    # convert to dict
    face_dict = ast.literal_eval(face_str)
    
    AgeList.append((face_dict['AgeRange']['High'] + face_dict['AgeRange']['Low']) / 2)
    
    BeardConfList.append(face_dict['Beard']['Confidence'])
    BeardValueList.append(face_dict['Beard']['Value'])
    
    EmotionsList = []
    for i in face_dict['Emotions']:
        EmotionsList.append(i['Type'])
        
    if 'HAPPY' in EmotionsList:
        EmotionIndex = EmotionsList.index('HAPPY')
        HappyList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        HappyList.append(0.0)
    
    if 'CONFUSED' in EmotionsList:
        EmotionIndex = EmotionsList.index('CONFUSED')
        ConfusedList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        ConfusedList.append(0.0)
        
    if 'CALM' in EmotionsList:
        EmotionIndex = EmotionsList.index('CALM')
        CalmList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        CalmList.append(0.0)
        
    if 'ANGRY' in EmotionsList:
        EmotionIndex = EmotionsList.index('ANGRY')
        AngryList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        AngryList.append(0.0)
        
    if 'SAD' in EmotionsList:
        EmotionIndex = EmotionsList.index('SAD')
        SadList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        SadList.append(0.0)
        
    if 'SURPRISED' in EmotionsList:
        EmotionIndex = EmotionsList.index('SURPRISED')
        SurprisedList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        SurprisedList.append(0.0)
        
    if 'DISGUSTED' in EmotionsList:
        EmotionIndex = EmotionsList.index('DISGUSTED')
        DisgustedList.append(face_dict['Emotions'][EmotionIndex]['Confidence'])
    else:
        DisgustedList.append(0.0)
    
            
    EyeglassesConfList.append(face_dict['Eyeglasses']['Confidence'])
    EyeglassesValueList.append(face_dict['Eyeglasses']['Value'])
    
    EyesOpenConfList.append(face_dict['EyesOpen']['Confidence'])
    EyesOpenValueList.append(face_dict['EyesOpen']['Value'])
    
    GenderConfList.append(face_dict['Gender']['Confidence'])
    GenderValueList.append(face_dict['Gender']['Value'])
    
    MouthOpenConfList.append(face_dict['MouthOpen']['Confidence'])
    MouthOpenValueList.append(face_dict['MouthOpen']['Value'])
    
    MustacheConfList.append(face_dict['Mustache']['Confidence'])
    MustacheValueList.append(face_dict['Mustache']['Value'])
    
    PitchList.append(face_dict['Pose']['Pitch'])
    RollList.append(face_dict['Pose']['Roll'])
    YawList.append(face_dict['Pose']['Yaw'])
    
    SmileConfList.append(face_dict['Smile']['Confidence'])
    SmileValueList.append(face_dict['Smile']['Value'])
    
    BrightnessList.append(face_dict['Quality']['Brightness'])
    SharpnessList.append(face_dict['Quality']['Sharpness'])
    
    SunglassesConfList.append(face_dict['Sunglasses']['Confidence'])
    SunglassesValueList.append(face_dict['Sunglasses']['Value'])

# %%
len(df)
# Out:
# 9525

# %%
print(len(AgeList), len(BeardConfList), len(BeardValueList), len(EyeglassesConfList),
      len(EyeglassesValueList), len(EyesOpenConfList), len(EyesOpenValueList), len(GenderConfList),
      len(GenderValueList), len(MouthOpenConfList), len(MouthOpenValueList), len(MustacheConfList),
      len(MustacheValueList), len(PitchList), len(RollList), len(YawList), len(SmileConfList), len(SmileValueList),
      len(BrightnessList), len(SharpnessList), len(SunglassesConfList), len(SunglassesValueList))
# Out:
# 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525 9525

# %%
print(len(HappyList), len(ConfusedList), len(CalmList), len(SadList), len(AngryList), len(SurprisedList), len(DisgustedList))
# Out:
# 9525 9525 9525 9525 9525 9525 9525

# %%
# add feature columns to dataframe

df['Age'] = AgeList

df['BeardConf'] = BeardConfList
df['BeardValue'] = BeardValueList

df['Happy'] = HappyList
df['Confused'] = ConfusedList
df['Calm'] = CalmList
df['Angry'] = AngryList
df['Sad'] = SadList
df['Surprised'] = SurprisedList
df['Disgusted'] = DisgustedList

df['EyeglassesConf'] = EyeglassesConfList
df['EyeglassesValue'] = EyeglassesValueList

df['EyesOpenConf'] = EyesOpenConfList
df['EyesOpenValue'] = EyesOpenValueList

df['GenderConf'] = GenderConfList
df['GenderValue'] = GenderValueList

df['MouthOpenConf'] = MouthOpenConfList
df['MouthOpenValue'] = MouthOpenValueList

df['MustacheConf'] = MustacheConfList
df['MustacheValue'] = MustacheValueList

df['Pitch'] = PitchList
df['Roll'] = RollList
df['Yaw'] = YawList

df['SmileConf'] = SmileConfList
df['SmileValue'] = SmileValueList

df['Brightness'] = BrightnessList
df['Sharpness'] = SharpnessList

df['SunglassesConf'] = SunglassesConfList
df['SunglassesValue'] = SunglassesValueList

# %%
df.head()
# Out:
#     index  GroupIndex              PhotoName  \
# 2       2           2   1001328126675771.jpg
# 4       4           4  10100238407492499.jpg
# 7       7           7  10100279131750930.jpg
# 9       9           9  10100367881175131.jpg
# 10     10          10  10100371498945180.jpg
#
#                                                Labels  \
# 2   [{'Name': 'People', 'Confidence': 99.012985229...
# 4   [{'Name': 'Human', 'Confidence': 99.3081130981...
# 7   [{'Name': 'People', 'Confidence': 98.705482482...
# 9   [{'Name': 'Human', 'Confidence': 99.3036804199...
# 10  [{'Name': 'Human', 'Confidence': 99.3256072998...
#
#                                           FaceDetails Personality IvsE SvsN  \
# 2   [{'BoundingBox': {'Width': 0.4146634638309479,...        ENFJ    E    N
# 4   [{'BoundingBox': {'Width': 0.6088888645172119,...        ENFJ    E    N
# 7   [{'BoundingBox': {'Width': 0.6666666865348816,...        ENFJ    E    N
# 9   [{'BoundingBox': {'Width': 0.39759817719459534...        ENFJ    E    N
# 10  [{'BoundingBox': {'Width': 0.4933333396911621,...        ENFJ    E    N
#
#     TvsF JvsP       ...         MustacheValue      Pitch       Roll  \
# 2   Feel    J       ...                 False  -8.956658  -5.676807
# 4   Feel    J       ...                 False -14.065570  33.765709
# 7   Feel    J       ...                  True  -1.285544   6.345731
# 9   Feel    J       ...                 False  -8.183560 -10.917071
# 10  Feel    J       ...                 False -17.491995  22.592890
#
#           Yaw  SmileConf  SmileValue  Brightness  Sharpness  SunglassesConf  \
# 2   -9.280488  62.861515        True   38.643616  99.998024       99.974411
# 4  -30.307148  99.733307        True   42.755604  99.984879       98.872681
# 7   12.106484  92.005432        True   42.692741  99.998024       96.547523
# 9    8.972569  95.709465        True   44.389008  99.994530       99.947449
# 10 -33.872795  94.382462        True   45.048271  99.974861       99.316338
#
#     SunglassesValue
# 2             False
# 4             False
# 7              True
# 9             False
# 10            False
#
# [5 rows x 39 columns]

# %%
df = df.drop(['GroupIndex','Labels','FaceDetails'], axis='columns')
df.head()
# Out:
#     index              PhotoName Personality IvsE SvsN  TvsF JvsP   Age  \
# 2       2   1001328126675771.jpg        ENFJ    E    N  Feel    J  27.5
# 4       4  10100238407492499.jpg        ENFJ    E    N  Feel    J  34.5
# 7       7  10100279131750930.jpg        ENFJ    E    N  Feel    J  29.0
# 9       9  10100367881175131.jpg        ENFJ    E    N  Feel    J  34.5
# 10     10  10100371498945180.jpg        ENFJ    E    N  Feel    J  43.5
#
#     BeardConf  BeardValue       ...         MustacheValue      Pitch  \
# 2   52.137314        True       ...                 False  -8.956658
# 4   99.997917       False       ...                 False -14.065570
# 7   95.081314        True       ...                  True  -1.285544
# 9   99.998543       False       ...                 False  -8.183560
# 10  84.941391       False       ...                 False -17.491995
#
#          Roll        Yaw  SmileConf  SmileValue  Brightness  Sharpness  \
# 2   -5.676807  -9.280488  62.861515        True   38.643616  99.998024
# 4   33.765709 -30.307148  99.733307        True   42.755604  99.984879
# 7    6.345731  12.106484  92.005432        True   42.692741  99.998024
# 9  -10.917071   8.972569  95.709465        True   44.389008  99.994530
# 10  22.592890 -33.872795  94.382462        True   45.048271  99.974861
#
#     SunglassesConf  SunglassesValue
# 2        99.974411            False
# 4        98.872681            False
# 7        96.547523             True
# 9        99.947449            False
# 10       99.316338            False
#
# [5 rows x 36 columns]

# %%
df.to_csv('CleanData.csv')
